# %%
from absenteeism_module import *

# %%
model = absenteeism_model('model', 'scaler')

# %%
import pandas as pd
data = pd.read_csv('Absenteeism_new_data.csv')

# %%
data.head()
# Out:
#    ID  Reason for Absence        Date  Transportation Expense  \
# 0  22                  27  01/06/2018                     179
# 1  10                   7  04/06/2018                     361
# 2  14                  23  06/06/2018                     155
# 3  17                  25  08/06/2018                     179
# 4  14                  10  08/06/2018                     155
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# 0                26   30                  237.656               19          3
# 1                52   28                  237.656               27          1
# 2                12   34                  237.656               25          1
# 3                22   40                  237.656               22          2
# 4                12   34                  237.656               25          1
#
#    Children  Pets
# 0         0     0
# 1         1     4
# 2         2     0
# 3         2     0
# 4         2     0

# %%
model.load_and_clean_data('Absenteeism_new_data.csv')

# %%
pred_data = model.predicted_outputs()

# %%
col_list = ['Reason_1', 'Reason_2', 'Reason_3', 'Reason_4']
pred_data[col_list] = pred_data[col_list].astype(int)

# %%
pred_data.head()
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0         0         0         0         1            6
# 1         1         0         0         0            6
# 2         0         0         0         1            6
# 3         0         0         0         1            6
# 4         1         0         0         0            6
#
#    Transportation Expense  Age  Body Mass Index  Education  Children  Pet  \
# 0                     179   30               19          1         0    0
# 1                     361   28               27          0         1    4
# 2                     155   34               25          0         2    0
# 3                     179   40               22          1         2    0
# 4                     155   34               25          0         2    0
#
#    Probability  Prediction
# 0     0.127203           0
# 1     0.864029           1
# 2     0.265096           0
# 3     0.202894           0
# 4     0.719413           1

# %%
pred_data.to_csv('Absenteeism_predictions.csv', index=False)
